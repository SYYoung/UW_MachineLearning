# %% [markdown]
# # Boosting a decision stump
#
# The goal of this notebook is to implement your own boosting module.
#
# **Brace yourselves**! This is going to be a fun and challenging assignment.
#
#
# * Use SFrames to do some feature engineering.
# * Modify the decision trees to incorporate weights.
# * Implement Adaboost ensembling.
# * Use your implementation of Adaboost to train a boosted decision stump ensemble.
# * Evaluate the effect of boosting (adding more decision stumps) on performance of the model.
# * Explore the robustness of Adaboost to overfitting.
#
# Let's get started!

# %% [markdown]
# ## Fire up GraphLab Create

# %% [markdown]
# Make sure you have the latest version of GraphLab Create **(1.8.3 or newer)**. Upgrade by
# ```
#    pip install graphlab-create --upgrade
# ```
# See [this page](https://dato.com/download/) for detailed instructions on upgrading.

# %%
import graphlab
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to r38411@yahoo.com and will expire on August 31, 2019.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1545972720.log

# %% [markdown]
# # Getting the data ready

# %% [markdown]
# We will be using the same [LendingClub](https://www.lendingclub.com/) dataset as in the previous assignment.

# %%
loans = graphlab.SFrame('lending-club-data.gl/')

# %% [markdown]
# ### Extracting the target and the feature columns
#
# We will now repeat some of the feature processing steps that we saw in the previous assignment:
#
# First, we re-assign the target to have +1 as a safe (good) loan, and -1 as a risky (bad) loan.
#
# Next, we select four categorical features:
# 1. grade of the loan
# 2. the length of the loan term
# 3. the home ownership status: own, mortgage, rent
# 4. number of years of employment.

# %%
features = ['grade',              # grade of the loan
            'term',               # the term of the loan
            'home_ownership',     # home ownership status: own, mortgage or rent
            'emp_length',         # number of years of employment
           ]
loans['safe_loans'] = loans['bad_loans'].apply(lambda x : +1 if x==0 else -1)
loans.remove_column('bad_loans')
target = 'safe_loans'
loans = loans[features + [target]]
loans
# Out:
# Columns:
# 	grade	str
# 	term	str
# 	home_ownership	str
# 	emp_length	str
# 	safe_loans	int
#
# Rows: 122607
#
# Data:
# +-------+------------+----------------+------------+------------+
# | grade |    term    | home_ownership | emp_length | safe_loans |
# +-------+------------+----------------+------------+------------+
# |   B   |  36 months |      RENT      | 10+ years  |     1      |
# |   C   |  60 months |      RENT      |  < 1 year  |     -1     |
# |   C   |  36 months |      RENT      | 10+ years  |     1      |
# |   C   |  36 months |      RENT      | 10+ years  |     1      |
# |   A   |  36 months |      RENT      |  3 years   |     1      |
# |   E   |  36 months |      RENT      |  9 years   |     1      |
# |   F   |  60 months |      OWN       |  4 years   |     -1     |
# |   B   |  60 months |      RENT      |  < 1 year  |     -1     |
# |   C   |  60 months |      OWN       |  5 years   |     1      |
# |   B   |  36 months |      OWN       | 10+ years  |     1      |
# +-------+------------+----------------+------------+------------+
# [122607 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ### Subsample dataset to make sure classes are balanced

# %% [markdown]
# Just as we did in the previous assignment, we will undersample the larger class (safe loans) in order to balance out our dataset. This means we are throwing away many data points. We use `seed=1` so everyone gets the same results.

# %%
safe_loans_raw = loans[loans[target] == 1]
risky_loans_raw = loans[loans[target] == -1]

# Undersample the safe loans.
percentage = len(risky_loans_raw)/float(len(safe_loans_raw))
risky_loans = risky_loans_raw
safe_loans = safe_loans_raw.sample(percentage, seed=1)
loans_data = risky_loans_raw.append(safe_loans)

print "Percentage of safe loans                 :", len(safe_loans) / float(len(loans_data))
print "Percentage of risky loans                :", len(risky_loans) / float(len(loans_data))
print "Total number of loans in our new dataset :", len(loans_data)
# Out:
# Percentage of safe loans                 : 0.502236174422
# Percentage of risky loans                : 0.497763825578
# Total number of loans in our new dataset : 46508

# %% [markdown]
# **Note:** There are many approaches for dealing with imbalanced data, including some where we modify the learning algorithm. These approaches are beyond the scope of this course, but some of them are reviewed in this [paper](http://ieeexplore.ieee.org/xpl/login.jsp?tp=&arnumber=5128907&url=http%3A%2F%2Fieeexplore.ieee.org%2Fiel5%2F69%2F5173046%2F05128907.pdf%3Farnumber%3D5128907 ). For this assignment, we use the simplest possible approach, where we subsample the overly represented class to get a more balanced dataset. In general, and especially when the data is highly imbalanced, we recommend using more advanced methods.

# %% [markdown]
# ### Transform categorical data into binary features

# %% [markdown]
# In this assignment, we will work with **binary decision trees**. Since all of our features are currently categorical features, we want to turn them into binary features using 1-hot encoding.
#
# We can do so with the following code block (see the first assignments for more details):

# %%
loans_data = risky_loans.append(safe_loans)
for feature in features:
    loans_data_one_hot_encoded = loans_data[feature].apply(lambda x: {x: 1})    
    loans_data_unpacked = loans_data_one_hot_encoded.unpack(column_name_prefix=feature)
    
    # Change None's to 0's
    for column in loans_data_unpacked.column_names():
        loans_data_unpacked[column] = loans_data_unpacked[column].fillna(0)

    loans_data.remove_column(feature)
    loans_data.add_columns(loans_data_unpacked)

# %% [markdown]
# Let's see what the feature columns look like now:

# %%
features = loans_data.column_names()
features.remove('safe_loans')  # Remove the response variable
features
# Out:
# ['grade.A',
#  'grade.B',
#  'grade.C',
#  'grade.D',
#  'grade.E',
#  'grade.F',
#  'grade.G',
#  'term. 36 months',
#  'term. 60 months',
#  'home_ownership.MORTGAGE',
#  'home_ownership.OTHER',
#  'home_ownership.OWN',
#  'home_ownership.RENT',
#  'emp_length.1 year',
#  'emp_length.10+ years',
#  'emp_length.2 years',
#  'emp_length.3 years',
#  'emp_length.4 years',
#  'emp_length.5 years',
#  'emp_length.6 years',
#  'emp_length.7 years',
#  'emp_length.8 years',
#  'emp_length.9 years',
#  'emp_length.< 1 year',
#  'emp_length.n/a']

# %% [markdown]
# ### Train-test split
#
# We split the data into training and test sets with 80% of the data in the training set and 20% of the data in the test set. We use `seed=1` so that everyone gets the same result.

# %%
train_data, test_data = loans_data.random_split(0.8, seed=1)

# %% [markdown]
# # Weighted decision trees

# %% [markdown]
# Let's modify our decision tree code from Module 5 to support weighting of individual data points.

# %% [markdown]
# ### Weighted error definition
#
# Consider a model with $N$ data points with:
# * Predictions $\hat{y}_1 ... \hat{y}_n$
# * Target $y_1 ... y_n$
# * Data point weights $\alpha_1 ... \alpha_n$.
#
# Then the **weighted error** is defined by:
# $$
# \mathrm{E}(\mathbf{\alpha}, \mathbf{\hat{y}}) = \frac{\sum_{i=1}^{n} \alpha_i \times 1[y_i \neq \hat{y_i}]}{\sum_{i=1}^{n} \alpha_i}
# $$
# where $1[y_i \neq \hat{y_i}]$ is an indicator function that is set to $1$ if $y_i \neq \hat{y_i}$.
#
#
# ### Write a function to compute weight of mistakes
#
# Write a function that calculates the weight of mistakes for making the "weighted-majority" predictions for a dataset. The function accepts two inputs:
# * `labels_in_node`: Targets $y_1 ... y_n$
# * `data_weights`: Data point weights $\alpha_1 ... \alpha_n$
#
# We are interested in computing the (total) weight of mistakes, i.e.
# $$
# \mathrm{WM}(\mathbf{\alpha}, \mathbf{\hat{y}}) = \sum_{i=1}^{n} \alpha_i \times 1[y_i \neq \hat{y_i}].
# $$
# This quantity is analogous to the number of mistakes, except that each mistake now carries different weight. It is related to the weighted error in the following way:
# $$
# \mathrm{E}(\mathbf{\alpha}, \mathbf{\hat{y}}) = \frac{\mathrm{WM}(\mathbf{\alpha}, \mathbf{\hat{y}})}{\sum_{i=1}^{n} \alpha_i}
# $$
#
# The function **intermediate_node_weighted_mistakes** should first compute two weights:
#  * $\mathrm{WM}_{-1}$: weight of mistakes when all predictions are $\hat{y}_i = -1$ i.e $\mathrm{WM}(\mathbf{\alpha}, \mathbf{-1}$)
#  * $\mathrm{WM}_{+1}$: weight of mistakes when all predictions are $\hat{y}_i = +1$ i.e $\mbox{WM}(\mathbf{\alpha}, \mathbf{+1}$)
#
#  where $\mathbf{-1}$ and $\mathbf{+1}$ are vectors where all values are -1 and +1 respectively.
#
# After computing $\mathrm{WM}_{-1}$ and $\mathrm{WM}_{+1}$, the function **intermediate_node_weighted_mistakes** should return the lower of the two weights of mistakes, along with the class associated with that weight. We have provided a skeleton for you with `YOUR CODE HERE` to be filled in several places.

# %%
def intermediate_node_weighted_mistakes(labels_in_node, data_weights):
    # Sum the weights of all entries with label +1
    total_weight_positive = data_weights[labels_in_node == +1].sum()
    
    # Weight of mistakes for predicting all -1's is equal to the sum above
    ### YOUR CODE HERE
    weighted_mistakes_all_negative = total_weight_positive
    
    # Sum the weights of all entries with label -1
    ### YOUR CODE HERE
    total_weight_negative = data_weights[labels_in_node==-1].sum()
    
    # Weight of mistakes for predicting all +1's is equal to the sum above
    ### YOUR CODE HERE
    weighted_mistakes_all_positive = total_weight_negative
    
    # Return the tuple (weight, class_label) representing the lower of the two weights
    #    class_label should be an integer of value +1 or -1.
    # If the two weights are identical, return (weighted_mistakes_all_positive,+1)
    ### YOUR CODE HERE
    if (total_weight_positive >= total_weight_negative):
        return (weighted_mistakes_all_positive, +1)
    else:
        return (weighted_mistakes_all_negative, -1)

# %% [markdown]
# **Checkpoint:** Test your **intermediate_node_weighted_mistakes** function, run the following cell:

# %%
example_labels = graphlab.SArray([-1, -1, 1, 1, 1])
example_data_weights = graphlab.SArray([1., 2., .5, 1., 1.])
if intermediate_node_weighted_mistakes(example_labels, example_data_weights) == (2.5, -1):
    print 'Test passed!'
else:
    print 'Test failed... try again!'
# Out:
# Test passed!

# %% [markdown]
# Recall that the **classification error** is defined as follows:
# $$
# \mbox{classification error} = \frac{\mbox{# mistakes}}{\mbox{# all data points}}
# $$
#
# **Quiz Question:** If we set the weights $\mathbf{\alpha} = 1$ for all data points, how is the weight of mistakes $\mbox{WM}(\mathbf{\alpha}, \mathbf{\hat{y}})$ related to the `classification error`?

# %% [markdown]
# ### Function to pick best feature to split on

# %% [markdown]
# We continue modifying our decision tree code from the earlier assignment to incorporate weighting of individual data points. The next step is to pick the best feature to split on.
#
# The **best_splitting_feature** function is similar to the one from the earlier assignment with two minor modifications:
#   1. The function **best_splitting_feature** should now accept an extra parameter `data_weights` to take account of weights of data points.
#   2. Instead of computing the number of mistakes in the left and right side of the split, we compute the weight of mistakes for both sides, add up the two weights, and divide it by the total weight of the data.
#
# Complete the following function. Comments starting with `DIFFERENT HERE` mark the sections where the weighted version differs from the original implementation.

# %%
def best_splitting_feature(data, features, target, data_weights):
    
    # These variables will keep track of the best feature and the corresponding error
    best_feature = None
    best_error = float('+inf') 
    num_points = float(len(data))

    # Loop through each feature to consider splitting on that feature
    for feature in features:
        
        # The left split will have all data points where the feature value is 0
        # The right split will have all data points where the feature value is 1
        print 'inside best_splitting_feature():, the current feature is: ', feature
        left_split = data[data[feature] == 0]
        right_split = data[data[feature] == 1]
        
        # Apply the same filtering to data_weights to create left_data_weights, right_data_weights
        ## YOUR CODE HERE
        left_data_weights = data_weights[data[feature]==0]
        right_data_weights = data_weights[data[feature]==1]
                    
        # DIFFERENT HERE
        # Calculate the weight of mistakes for left and right sides
        ## YOUR CODE HERE
        left_weighted_mistakes, left_class = intermediate_node_weighted_mistakes(left_split[target], left_data_weights)
        right_weighted_mistakes, right_class = intermediate_node_weighted_mistakes(right_split[target], right_data_weights)
        
        # DIFFERENT HERE
        # Compute weighted error by computing
        #  ( [weight of mistakes (left)] + [weight of mistakes (right)] ) / [total weight of all data points]
        ## YOUR CODE HERE
        print 'inside best_feature_split(): left_weighted_mistakes = ', left_weighted_mistakes
        print ', right_weighted_mistakes = ', right_weighted_mistakes, ', sum of data_weights = ', sum(data_weights)
        error = (left_weighted_mistakes + right_weighted_mistakes) *1.0/ sum(data_weights)
        
        # If this is the best error we have found so far, store the feature and the error
        if error < best_error:
            best_feature = feature
            best_error = error
    
    # Return the best feature we found
    return best_feature

# %% [markdown]
# **Checkpoint:** Now, we have another checkpoint to make sure you are on the right track.

# %%
example_data_weights = graphlab.SArray(len(train_data)* [1.5])
if best_splitting_feature(train_data, features, target, example_data_weights) == 'term. 36 months':
    print 'Test passed!'
else:
    print 'Test failed... try again!'
# Out:
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  22314.0
# , right_weighted_mistakes =  1887.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  19087.5
# , right_weighted_mistakes =  6514.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  20343.0
# , right_weighted_mistakes =  6747.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  21600.0
# , right_weighted_mistakes =  4024.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  24252.0
# , right_weighted_mistakes =  1651.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  25839.0
# , right_weighted_mistakes =  693.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  27223.5
# , right_weighted_mistakes =  163.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  4831.5
# , right_weighted_mistakes =  18711.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  18711.0
# , right_weighted_mistakes =  4831.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  14074.5
# , right_weighted_mistakes =  12019.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  27664.5
# , right_weighted_mistakes =  42.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  25374.0
# , right_weighted_mistakes =  2272.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  14409.0
# , right_weighted_mistakes =  11760.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  25785.0
# , right_weighted_mistakes =  1929.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  20125.5
# , right_weighted_mistakes =  7588.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  25149.0
# , right_weighted_mistakes =  2565.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  25450.5
# , right_weighted_mistakes =  2263.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  25887.0
# , right_weighted_mistakes =  1827.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  25561.5
# , right_weighted_mistakes =  2152.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  25927.5
# , right_weighted_mistakes =  1692.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  26140.5
# , right_weighted_mistakes =  1468.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  26497.5
# , right_weighted_mistakes =  1209.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  26716.5
# , right_weighted_mistakes =  997.5 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  25227.0
# , right_weighted_mistakes =  2487.0 , sum of data_weights =  55836.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  26386.5
# , right_weighted_mistakes =  837.0 , sum of data_weights =  55836.0
# Test passed!

# %% [markdown]
# **Note**. If you get an exception in the line of "the logical filter has different size than the array", try upgradting your GraphLab Create installation to 1.8.3 or newer.

# %% [markdown]
# **Very Optional**. Relationship between weighted error and weight of mistakes
#
# By definition, the weighted error is the weight of mistakes divided by the weight of all data points, so
# $$
# \mathrm{E}(\mathbf{\alpha}, \mathbf{\hat{y}}) = \frac{\sum_{i=1}^{n} \alpha_i \times 1[y_i \neq \hat{y_i}]}{\sum_{i=1}^{n} \alpha_i} = \frac{\mathrm{WM}(\mathbf{\alpha}, \mathbf{\hat{y}})}{\sum_{i=1}^{n} \alpha_i}.
# $$
#
# In the code above, we obtain $\mathrm{E}(\mathbf{\alpha}, \mathbf{\hat{y}})$ from the two weights of mistakes from both sides, $\mathrm{WM}(\mathbf{\alpha}_{\mathrm{left}}, \mathbf{\hat{y}}_{\mathrm{left}})$ and $\mathrm{WM}(\mathbf{\alpha}_{\mathrm{right}}, \mathbf{\hat{y}}_{\mathrm{right}})$. First, notice that the overall weight of mistakes $\mathrm{WM}(\mathbf{\alpha}, \mathbf{\hat{y}})$ can be broken into two weights of mistakes over either side of the split:
# $$
# \mathrm{WM}(\mathbf{\alpha}, \mathbf{\hat{y}})
# = \sum_{i=1}^{n} \alpha_i \times 1[y_i \neq \hat{y_i}]
# = \sum_{\mathrm{left}} \alpha_i \times 1[y_i \neq \hat{y_i}]
#  + \sum_{\mathrm{right}} \alpha_i \times 1[y_i \neq \hat{y_i}]\\
# = \mathrm{WM}(\mathbf{\alpha}_{\mathrm{left}}, \mathbf{\hat{y}}_{\mathrm{left}}) + \mathrm{WM}(\mathbf{\alpha}_{\mathrm{right}}, \mathbf{\hat{y}}_{\mathrm{right}})
# $$
# We then divide through by the total weight of all data points to obtain $\mathrm{E}(\mathbf{\alpha}, \mathbf{\hat{y}})$:
# $$
# \mathrm{E}(\mathbf{\alpha}, \mathbf{\hat{y}})
# = \frac{\mathrm{WM}(\mathbf{\alpha}_{\mathrm{left}}, \mathbf{\hat{y}}_{\mathrm{left}}) + \mathrm{WM}(\mathbf{\alpha}_{\mathrm{right}}, \mathbf{\hat{y}}_{\mathrm{right}})}{\sum_{i=1}^{n} \alpha_i}
# $$

# %% [markdown]
# ### Building the tree
#
# With the above functions implemented correctly, we are now ready to build our decision tree. Recall from the previous assignments that each node in the decision tree is represented as a dictionary which contains the following keys:
#
#     {
#        'is_leaf'            : True/False.
#        'prediction'         : Prediction at the leaf node.
#        'left'               : (dictionary corresponding to the left tree).
#        'right'              : (dictionary corresponding to the right tree).
#        'features_remaining' : List of features that are posible splits.
#     }
#
# Let us start with a function that creates a leaf node given a set of target values:

# %%
def create_leaf(target_values, data_weights):
    
    # Create a leaf node
    leaf = {'splitting_feature' : None,
            'is_leaf': True}
    
    # Computed weight of mistakes.
    weighted_error, best_class = intermediate_node_weighted_mistakes(target_values, data_weights)
    # Store the predicted class (1 or -1) in leaf['prediction']
    leaf['prediction'] = best_class
    
    return leaf

# %% [markdown]
# We provide a function that learns a weighted decision tree recursively and implements 3 stopping conditions:
# 1. All data points in a node are from the same class.
# 2. No more features to split on.
# 3. Stop growing the tree when the tree depth reaches **max_depth**.

# %%
def weighted_decision_tree_create(data, features, target, data_weights, current_depth = 1, max_depth = 10):
    remaining_features = features[:] # Make a copy of the features.
    target_values = data[target]
    print "--------------------------------------------------------------------"
    print "Subtree, depth = %s (%s data points)." % (current_depth, len(target_values))
    
    # Stopping condition 1. Error is 0.
    if intermediate_node_weighted_mistakes(target_values, data_weights)[0] <= 1e-15:
        print "Stopping condition 1 reached."                
        return create_leaf(target_values, data_weights)
    
    # Stopping condition 2. No more features.
    if remaining_features == []:
        print "Stopping condition 2 reached."                
        return create_leaf(target_values, data_weights)    
    
    # Additional stopping condition (limit tree depth)
    if current_depth > max_depth:
        print "Reached maximum depth. Stopping for now."
        return create_leaf(target_values, data_weights)
    
    splitting_feature = best_splitting_feature(data, features, target, data_weights)
    remaining_features.remove(splitting_feature)
        
    left_split = data[data[splitting_feature] == 0]
    right_split = data[data[splitting_feature] == 1]
    
    left_data_weights = data_weights[data[splitting_feature] == 0]
    right_data_weights = data_weights[data[splitting_feature] == 1]
    
    print "Split on feature %s. (%s, %s)" % (\
              splitting_feature, len(left_split), len(right_split))
    
    # Create a leaf node if the split is "perfect"
    if len(left_split) == len(data):
        print "Creating leaf node."
        return create_leaf(left_split[target], data_weights)
    if len(right_split) == len(data):
        print "Creating leaf node."
        return create_leaf(right_split[target], data_weights)
    
    # Repeat (recurse) on left and right subtrees
    left_tree = weighted_decision_tree_create(
        left_split, remaining_features, target, left_data_weights, current_depth + 1, max_depth)
    right_tree = weighted_decision_tree_create(
        right_split, remaining_features, target, right_data_weights, current_depth + 1, max_depth)
    
    return {'is_leaf'          : False, 
            'prediction'       : None,
            'splitting_feature': splitting_feature,
            'left'             : left_tree, 
            'right'            : right_tree}

# %% [markdown]
# Here is a recursive function to count the nodes in your tree:

# %%
def count_nodes(tree):
    if tree['is_leaf']:
        return 1
    return 1 + count_nodes(tree['left']) + count_nodes(tree['right'])

# %% [markdown]
# Run the following test code to check your implementation. Make sure you get **'Test passed'** before proceeding.

# %%
example_data_weights = graphlab.SArray([1.0 for i in range(len(train_data))])
small_data_decision_tree = weighted_decision_tree_create(train_data, features, target,
                                        example_data_weights, max_depth=2)
if count_nodes(small_data_decision_tree) == 7:
    print 'Test passed!'
else:
    print 'Test failed... try again!'
    print 'Number of nodes found:', count_nodes(small_data_decision_tree)
    print 'Number of nodes that should be there: 7'
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  14876.0
# , right_weighted_mistakes =  1258.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  12725.0
# , right_weighted_mistakes =  4343.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  13562.0
# , right_weighted_mistakes =  4498.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  14400.0
# , right_weighted_mistakes =  2683.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  16168.0
# , right_weighted_mistakes =  1101.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  17226.0
# , right_weighted_mistakes =  462.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  18149.0
# , right_weighted_mistakes =  109.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  3221.0
# , right_weighted_mistakes =  12474.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  12474.0
# , right_weighted_mistakes =  3221.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  9383.0
# , right_weighted_mistakes =  8013.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  18443.0
# , right_weighted_mistakes =  28.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  16916.0
# , right_weighted_mistakes =  1515.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  9606.0
# , right_weighted_mistakes =  7840.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  17190.0
# , right_weighted_mistakes =  1286.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  13417.0
# , right_weighted_mistakes =  5059.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  16766.0
# , right_weighted_mistakes =  1710.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  16967.0
# , right_weighted_mistakes =  1509.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  17258.0
# , right_weighted_mistakes =  1218.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  17041.0
# , right_weighted_mistakes =  1435.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  17285.0
# , right_weighted_mistakes =  1128.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  17427.0
# , right_weighted_mistakes =  979.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  17665.0
# , right_weighted_mistakes =  806.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  17811.0
# , right_weighted_mistakes =  665.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  16818.0
# , right_weighted_mistakes =  1658.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  17591.0
# , right_weighted_mistakes =  558.0 , sum of data_weights =  37224.0
# Split on feature term. 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9223 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  3159.0
# , right_weighted_mistakes =  39.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  2760.0
# , right_weighted_mistakes =  461.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  2307.0
# , right_weighted_mistakes =  914.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  2498.0
# , right_weighted_mistakes =  723.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  2597.0
# , right_weighted_mistakes =  624.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  2867.0
# , right_weighted_mistakes =  354.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  3138.0
# , right_weighted_mistakes =  83.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.0
# , right_weighted_mistakes =  3221.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  1254.0
# , right_weighted_mistakes =  1967.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  3220.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  2982.0
# , right_weighted_mistakes =  239.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  2207.0
# , right_weighted_mistakes =  1014.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  3045.0
# , right_weighted_mistakes =  176.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  2082.0
# , right_weighted_mistakes =  1139.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  2942.0
# , right_weighted_mistakes =  279.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  2984.0
# , right_weighted_mistakes =  237.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  3013.0
# , right_weighted_mistakes =  208.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  2964.0
# , right_weighted_mistakes =  257.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  3048.0
# , right_weighted_mistakes =  173.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  3030.0
# , right_weighted_mistakes =  191.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  3073.0
# , right_weighted_mistakes =  148.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  3096.0
# , right_weighted_mistakes =  125.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  2988.0
# , right_weighted_mistakes =  233.0 , sum of data_weights =  9223.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  3166.0
# , right_weighted_mistakes =  55.0 , sum of data_weights =  9223.0
# Split on feature grade.A. (9122, 101)
# --------------------------------------------------------------------
# Subtree, depth = 3 (9122 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 3 (101 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (28001 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  11255.0
# , right_weighted_mistakes =  1219.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  8718.0
# , right_weighted_mistakes =  3756.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  8836.0
# , right_weighted_mistakes =  3584.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  9733.0
# , right_weighted_mistakes =  1960.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  11675.0
# , right_weighted_mistakes =  477.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  12224.0
# , right_weighted_mistakes =  108.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  12403.0
# , right_weighted_mistakes =  26.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  12474.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  7623.0
# , right_weighted_mistakes =  4851.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  12443.0
# , right_weighted_mistakes =  27.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  11392.0
# , right_weighted_mistakes =  1082.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  5964.0
# , right_weighted_mistakes =  6510.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  11536.0
# , right_weighted_mistakes =  938.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  9391.0
# , right_weighted_mistakes =  3083.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  11256.0
# , right_weighted_mistakes =  1218.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  11409.0
# , right_weighted_mistakes =  1065.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  11624.0
# , right_weighted_mistakes =  850.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  11497.0
# , right_weighted_mistakes =  977.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  11668.0
# , right_weighted_mistakes =  806.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  11785.0
# , right_weighted_mistakes =  689.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  11943.0
# , right_weighted_mistakes =  531.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  12072.0
# , right_weighted_mistakes =  402.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  11273.0
# , right_weighted_mistakes =  1201.0 , sum of data_weights =  28001.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  11760.0
# , right_weighted_mistakes =  503.0 , sum of data_weights =  28001.0
# Split on feature grade.D. (23300, 4701)
# --------------------------------------------------------------------
# Subtree, depth = 3 (23300 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 3 (4701 data points).
# Reached maximum depth. Stopping for now.
# Test passed!

# %% [markdown]
# Let us take a quick look at what the trained tree is like. You should get something that looks like the following
#
# ```
# {'is_leaf': False,
#     'left': {'is_leaf': False,
#         'left': {'is_leaf': True, 'prediction': -1, 'splitting_feature': None},
#         'prediction': None,
#         'right': {'is_leaf': True, 'prediction': 1, 'splitting_feature': None},
#         'splitting_feature': 'grade.A'
#      },
#     'prediction': None,
#     'right': {'is_leaf': False,
#         'left': {'is_leaf': True, 'prediction': 1, 'splitting_feature': None},
#         'prediction': None,
#         'right': {'is_leaf': True, 'prediction': -1, 'splitting_feature': None},
#         'splitting_feature': 'grade.D'
#      },
#      'splitting_feature': 'term. 36 months'
# }```

# %%
small_data_decision_tree
# Out:
# {'is_leaf': False,
#  'left': {'is_leaf': False,
#   'left': {'is_leaf': True, 'prediction': -1, 'splitting_feature': None},
#   'prediction': None,
#   'right': {'is_leaf': True, 'prediction': 1, 'splitting_feature': None},
#   'splitting_feature': 'grade.A'},
#  'prediction': None,
#  'right': {'is_leaf': False,
#   'left': {'is_leaf': True, 'prediction': 1, 'splitting_feature': None},
#   'prediction': None,
#   'right': {'is_leaf': True, 'prediction': -1, 'splitting_feature': None},
#   'splitting_feature': 'grade.D'},
#  'splitting_feature': 'term. 36 months'}

# %% [markdown]
# ### Making predictions with a weighted decision tree

# %% [markdown]
# We give you a function that classifies one data point. It can also return the probability if you want to play around with that as well.

# %%
def classify(tree, x, annotate = False):   
    # If the node is a leaf node.
    if tree['is_leaf']:
        if annotate: 
            print "At leaf, predicting %s" % tree['prediction']
        return tree['prediction'] 
    else:
        # Split on feature.
        split_feature_value = x[tree['splitting_feature']]
        if annotate: 
            print "Split on %s = %s" % (tree['splitting_feature'], split_feature_value)
        if split_feature_value == 0:
            return classify(tree['left'], x, annotate)
        else:
            return classify(tree['right'], x, annotate)

# %% [markdown]
# ### Evaluating the tree
#
# Now, we will write a function to evaluate a decision tree by computing the classification error of the tree on the given dataset.
#
# Again, recall that the **classification error** is defined as follows:
# $$
# \mbox{classification error} = \frac{\mbox{# mistakes}}{\mbox{# all data points}}
# $$
#
# The function called **evaluate_classification_error** takes in as input:
# 1. `tree` (as described above)
# 2. `data` (an SFrame)
#
# The function does not change because of adding data point weights.

# %%
def evaluate_classification_error(tree, data):
    # Apply the classify(tree, x) to each row in your data
    prediction = data.apply(lambda x: classify(tree, x))
    
    # Once you've made the predictions, calculate the classification error
    return (prediction != data[target]).sum() / float(len(data))

# %%
evaluate_classification_error(small_data_decision_tree, test_data)
# Out:
# 0.3981042654028436

# %% [markdown]
# ### Example: Training a weighted decision tree
#
# To build intuition on how weighted data points affect the tree being built, consider the following:
#
# Suppose we only care about making good predictions for the **first 10 and last 10 items** in `train_data`, we assign weights:
# * 1 to the last 10 items
# * 1 to the first 10 items
# * and 0 to the rest.
#
# Let us fit a weighted decision tree with `max_depth = 2`.

# %%
# Assign weights
example_data_weights = graphlab.SArray([1.] * 10 + [0.]*(len(train_data) - 20) + [1.] * 10)

# Train a weighted decision tree model.
small_data_decision_tree_subset_20 = weighted_decision_tree_create(train_data, features, target,
                         example_data_weights, max_depth=2)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  9.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  5.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  5.0
# , right_weighted_mistakes =  4.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  8.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  10.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  9.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  9.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  3.0
# , right_weighted_mistakes =  6.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  6.0
# , right_weighted_mistakes =  3.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  3.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  10.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  8.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  8.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  8.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  10.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  9.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  8.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  9.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  9.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  10.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  9.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  9.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  7.0
# , right_weighted_mistakes =  2.0 , sum of data_weights =  20.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  10.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  20.0
# Split on feature home_ownership.RENT. (20514, 16710)
# --------------------------------------------------------------------
# Subtree, depth = 2 (20514 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  2.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  11.0
# Split on feature grade.F. (19613, 901)
# --------------------------------------------------------------------
# Subtree, depth = 3 (19613 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 3 (901 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (16710 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.0
# , right_weighted_mistakes =  1.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  1.0
# , right_weighted_mistakes =  0.0 , sum of data_weights =  9.0
# Split on feature grade.D. (13315, 3395)
# --------------------------------------------------------------------
# Subtree, depth = 3 (13315 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (3395 data points).
# Stopping condition 1 reached.

# %% [markdown]
# Now, we will compute the classification error on the `subset_20`, i.e. the subset of data points whose weight is 1 (namely the first and last 10 data points).

# %%
subset_20 = train_data.head(10).append(train_data.tail(10))
evaluate_classification_error(small_data_decision_tree_subset_20, subset_20)
# Out:
# 0.05

# %% [markdown]
# Now, let us compare the classification error of the model `small_data_decision_tree_subset_20` on the entire test set `train_data`:

# %%
evaluate_classification_error(small_data_decision_tree_subset_20, train_data)
# Out:
# 0.48124865678057166

# %% [markdown]
# The model `small_data_decision_tree_subset_20` performs **a lot** better on `subset_20` than on `train_data`.
#
# So, what does this mean?
# * The points with higher weights are the ones that are more important during the training process of the weighted decision tree.
# * The points with zero weights are basically ignored during training.
#
# **Quiz Question**: Will you get the same model as `small_data_decision_tree_subset_20` if you trained a decision tree with only the 20 data points with non-zero weights from the set of points in `subset_20`?

# %% [markdown]
# # Implementing your own Adaboost (on decision stumps)

# %% [markdown]
# Now that we have a weighted decision tree working, it takes only a bit of work to implement Adaboost. For the sake of simplicity, let us stick with **decision tree stumps** by training trees with **`max_depth=1`**.

# %% [markdown]
# Recall from the lecture the procedure for Adaboost:
#
# 1\. Start with unweighted data with $\alpha_j = 1$
#
# 2\. For t = 1,...T:
#   * Learn $f_t(x)$ with data weights $\alpha_j$
#   * Compute coefficient $\hat{w}_t$:
#      $$\hat{w}_t = \frac{1}{2}\ln{\left(\frac{1- \mbox{E}(\mathbf{\alpha}, \mathbf{\hat{y}})}{\mbox{E}(\mathbf{\alpha}, \mathbf{\hat{y}})}\right)}$$
#   * Re-compute weights $\alpha_j$:
#      $$\alpha_j \gets \begin{cases}
#      \alpha_j \exp{(-\hat{w}_t)} & \text{ if }f_t(x_j) = y_j\\
#      \alpha_j \exp{(\hat{w}_t)} & \text{ if }f_t(x_j) \neq y_j
#      \end{cases}$$
#   * Normalize weights $\alpha_j$:
#       $$\alpha_j \gets \frac{\alpha_j}{\sum_{i=1}^{N}{\alpha_i}} $$
#
# Complete the skeleton for the following code to implement **adaboost_with_tree_stumps**. Fill in the places with `YOUR CODE HERE`.

# %%
pred1 = graphlab.SArray([0, 1, 0, 1, 1])
act1 = graphlab.SArray([0, 0, 1, 1, 0])
val = pred1==act1
print val
a2 = graphlab.SArray([5, 10, 15, 20, 25])
a3 = a2[val]
print 'len of a3 = ', len(a3), a3
# Out:
# [1, 0, 0, 1, 0]
# len of a3 =  2 [5, 20]

# %%
from math import log
from math import exp

def adaboost_with_tree_stumps(data, features, target, num_tree_stumps):
    # start with unweighted data
    alpha = graphlab.SArray([1.]*len(data))
    weights = []
    tree_stumps = []
    target_values = data[target]
    
    for t in xrange(num_tree_stumps):
        print '====================================================='
        print 'Adaboost Iteration %d' % t
        print '====================================================='        
        # Learn a weighted decision tree stump. Use max_depth=1
        tree_stump = weighted_decision_tree_create(data, features, target, data_weights=alpha, max_depth=1)
        tree_stumps.append(tree_stump)
        
        # Make predictions
        predictions = data.apply(lambda x: classify(tree_stump, x))
        
        # Produce a Boolean array indicating whether
        # each data point was correctly classified
        is_correct = predictions == target_values
        is_wrong   = predictions != target_values
        
        # Compute weighted error
        # YOUR CODE HERE
        weighted_error = sum(alpha[is_wrong])/float(sum(alpha))
        print 'weight_error = ', weighted_error
        
        # Compute model coefficient using weighted error
        # YOUR CODE HERE
        weight = 0.5 * log((1 - weighted_error)/float(weighted_error))
        weights.append(weight)
        print 'weights = ', weight
        
        # Adjust weights on data point
        adjustment = graphlab.SArray(is_correct.apply(lambda x : exp(-weight) if x else exp(weight)))
        
        # Scale alpha by multiplying by adjustment 
        # Then normalize data points weights
        ## YOUR CODE HERE 
        total_alpha = sum(alpha[is_correct]) * exp(-weight) + sum(alpha[is_wrong])* exp(weight)
        print 'total_alpha = ', total_alpha
        alpha = alpha * adjustment/total_alpha
        
        print 'after adjusting, the correct data weights = ', alpha[is_correct][0:5]
        print 'after adjusting, the wrong data weights = ', alpha[is_wrong][0:5]
    
    return weights, tree_stumps

# %% [markdown]
# ### Checking your Adaboost code
#
# Train an ensemble of **two** tree stumps and see which features those stumps split on. We will run the algorithm with the following parameters:
# * `train_data`
# * `features`
# * `target`
# * `num_tree_stumps = 2`

# %%
stump_weights, tree_stumps = adaboost_with_tree_stumps(train_data, features, target, num_tree_stumps=2)
# Out:
# =====================================================
# Adaboost Iteration 0
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  14876.0
# , right_weighted_mistakes =  1258.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  12725.0
# , right_weighted_mistakes =  4343.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  13562.0
# , right_weighted_mistakes =  4498.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  14400.0
# , right_weighted_mistakes =  2683.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  16168.0
# , right_weighted_mistakes =  1101.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  17226.0
# , right_weighted_mistakes =  462.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  18149.0
# , right_weighted_mistakes =  109.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  3221.0
# , right_weighted_mistakes =  12474.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  12474.0
# , right_weighted_mistakes =  3221.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  9383.0
# , right_weighted_mistakes =  8013.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  18443.0
# , right_weighted_mistakes =  28.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  16916.0
# , right_weighted_mistakes =  1515.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  9606.0
# , right_weighted_mistakes =  7840.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  17190.0
# , right_weighted_mistakes =  1286.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  13417.0
# , right_weighted_mistakes =  5059.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  16766.0
# , right_weighted_mistakes =  1710.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  16967.0
# , right_weighted_mistakes =  1509.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  17258.0
# , right_weighted_mistakes =  1218.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  17041.0
# , right_weighted_mistakes =  1435.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  17285.0
# , right_weighted_mistakes =  1128.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  17427.0
# , right_weighted_mistakes =  979.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  17665.0
# , right_weighted_mistakes =  806.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  17811.0
# , right_weighted_mistakes =  665.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  16818.0
# , right_weighted_mistakes =  1658.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  17591.0
# , right_weighted_mistakes =  558.0 , sum of data_weights =  37224.0
# Split on feature term. 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9223 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (28001 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.421636578551
# weights =  0.158029336593
# total_alpha =  36763.9853661
# after adjusting, the correct data weights =  [2.3224487900041803e-05, 2.3224487900041803e-05, 2.3224487900041803e-05, 2.3224487900041803e-05, 2.3224487900041803e-05]
# after adjusting, the wrong data weights =  [3.185727938834023e-05, 3.185727938834023e-05, 3.185727938834023e-05, 3.185727938834023e-05, 3.185727938834023e-05]
# =====================================================
# Adaboost Iteration 1
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.372758470313
# , right_weighted_mistakes =  0.0397397786025 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.319358113036
# , right_weighted_mistakes =  0.13328871578 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.350864802539
# , right_weighted_mistakes =  0.112354117995 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.394666111252
# , right_weighted_mistakes =  0.0685528092819 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.432261897467
# , right_weighted_mistakes =  0.0309570230666 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.449433198937
# , right_weighted_mistakes =  0.0137857215967 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.459970929659
# , right_weighted_mistakes =  0.00324799087463 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.10261229691
# , right_weighted_mistakes =  0.360606623624 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.360606623624
# , right_weighted_mistakes =  0.10261229691 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.228740890492
# , right_weighted_mistakes =  0.227975493053 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.462560002081
# , right_weighted_mistakes =  0.000658918452689 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.4259705842
# , right_weighted_mistakes =  0.0372483363343 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.272385284828
# , right_weighted_mistakes =  0.190833635705 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.431182572131
# , right_weighted_mistakes =  0.0320363484026 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.331132466723
# , right_weighted_mistakes =  0.132086453811 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.417566375239
# , right_weighted_mistakes =  0.0456525452951 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.423642176505
# , right_weighted_mistakes =  0.0395767440292 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.428607098501
# , right_weighted_mistakes =  0.0346118220323 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.427510581569
# , right_weighted_mistakes =  0.0357083389644 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.435528225255
# , right_weighted_mistakes =  0.0276906952787 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.438833283705
# , right_weighted_mistakes =  0.0243856368284 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.443222330146
# , right_weighted_mistakes =  0.0199965903877 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.446579414705
# , right_weighted_mistakes =  0.0166395058291 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.421818748639
# , right_weighted_mistakes =  0.0414001718952 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.449784852754
# , right_weighted_mistakes =  0.0134340677801 , sum of data_weights =  1.0
# Split on feature grade.A. (32094, 5130)
# --------------------------------------------------------------------
# Subtree, depth = 2 (32094 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (5130 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.412498248915
# weights =  0.176823632936
# total_alpha =  0.984567810884
# after adjusting, the correct data weights =  [1.9765462704711265e-05, 1.9765462704711265e-05, 1.9765462704711265e-05, 2.711249739214583e-05, 2.711249739214583e-05]
# after adjusting, the wrong data weights =  [3.861504803006748e-05, 3.861504803006748e-05, 3.861504803006748e-05, 3.861504803006748e-05, 3.861504803006748e-05]

# %%
def print_stump(tree):
    split_name = tree['splitting_feature'] # split_name is something like 'term. 36 months'
    if split_name is None:
        print "(leaf, label: %s)" % tree['prediction']
        return None
    split_feature, split_value = split_name.split('.')
    print '                       root'
    print '         |---------------|----------------|'
    print '         |                                |'
    print '         |                                |'
    print '         |                                |'
    print '  [{0} == 0]{1}[{0} == 1]    '.format(split_name, ' '*(27-len(split_name)))
    print '         |                                |'
    print '         |                                |'
    print '         |                                |'
    print '    (%s)                 (%s)' \
        % (('leaf, label: ' + str(tree['left']['prediction']) if tree['left']['is_leaf'] else 'subtree'),
           ('leaf, label: ' + str(tree['right']['prediction']) if tree['right']['is_leaf'] else 'subtree'))

# %% [markdown]
# Here is what the first stump looks like:

# %%
print_stump(tree_stumps[0])
# Out:
#                        root
#          |---------------|----------------|
#          |                                |
#          |                                |
#          |                                |
#   [term. 36 months == 0]            [term. 36 months == 1]
#          |                                |
#          |                                |
#          |                                |
#     (leaf, label: -1)                 (leaf, label: 1)

# %% [markdown]
# Here is what the next stump looks like:

# %%
print_stump(tree_stumps[1])
# Out:
#                        root
#          |---------------|----------------|
#          |                                |
#          |                                |
#          |                                |
#   [grade.A == 0]                    [grade.A == 1]
#          |                                |
#          |                                |
#          |                                |
#     (leaf, label: -1)                 (leaf, label: 1)

# %%
print stump_weights
# Out:
# [0.15802933659263743, 0.17682363293639866]

# %% [markdown]
# If your Adaboost is correctly implemented, the following things should be true:
#
# * `tree_stumps[0]` should split on **term. 36 months** with the prediction -1 on the left and +1 on the right.
# * `tree_stumps[1]` should split on **grade.A** with the prediction -1 on the left and +1 on the right.
# * Weights should be approximately `[0.158, 0.177]`
#
# **Reminders**
# - Stump weights ($\mathbf{\hat{w}}$) and data point weights ($\mathbf{\alpha}$) are two different concepts.
# - Stump weights ($\mathbf{\hat{w}}$) tell you how important each stump is while making predictions with the entire boosted ensemble.
# - Data point weights ($\mathbf{\alpha}$) tell you how important each data point is while training a decision stump.

# %% [markdown]
# ### Training a boosted ensemble of 10 stumps

# %% [markdown]
# Let us train an ensemble of 10 decision tree stumps with Adaboost. We run the **adaboost_with_tree_stumps** function with the following parameters:
# * `train_data`
# * `features`
# * `target`
# * `num_tree_stumps = 10`

# %%
stump_weights, tree_stumps = adaboost_with_tree_stumps(train_data, features, 
                                target, num_tree_stumps=10)
# Out:
# =====================================================
# Adaboost Iteration 0
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  14876.0
# , right_weighted_mistakes =  1258.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  12725.0
# , right_weighted_mistakes =  4343.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  13562.0
# , right_weighted_mistakes =  4498.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  14400.0
# , right_weighted_mistakes =  2683.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  16168.0
# , right_weighted_mistakes =  1101.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  17226.0
# , right_weighted_mistakes =  462.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  18149.0
# , right_weighted_mistakes =  109.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  3221.0
# , right_weighted_mistakes =  12474.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  12474.0
# , right_weighted_mistakes =  3221.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  9383.0
# , right_weighted_mistakes =  8013.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  18443.0
# , right_weighted_mistakes =  28.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  16916.0
# , right_weighted_mistakes =  1515.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  9606.0
# , right_weighted_mistakes =  7840.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  17190.0
# , right_weighted_mistakes =  1286.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  13417.0
# , right_weighted_mistakes =  5059.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  16766.0
# , right_weighted_mistakes =  1710.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  16967.0
# , right_weighted_mistakes =  1509.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  17258.0
# , right_weighted_mistakes =  1218.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  17041.0
# , right_weighted_mistakes =  1435.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  17285.0
# , right_weighted_mistakes =  1128.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  17427.0
# , right_weighted_mistakes =  979.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  17665.0
# , right_weighted_mistakes =  806.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  17811.0
# , right_weighted_mistakes =  665.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  16818.0
# , right_weighted_mistakes =  1658.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  17591.0
# , right_weighted_mistakes =  558.0 , sum of data_weights =  37224.0
# Split on feature term. 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9223 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (28001 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.421636578551
# weights =  0.158029336593
# total_alpha =  36763.9853661
# after adjusting, the correct data weights =  [2.3224487900041803e-05, 2.3224487900041803e-05, 2.3224487900041803e-05, 2.3224487900041803e-05, 2.3224487900041803e-05]
# after adjusting, the wrong data weights =  [3.185727938834023e-05, 3.185727938834023e-05, 3.185727938834023e-05, 3.185727938834023e-05, 3.185727938834023e-05]
# =====================================================
# Adaboost Iteration 1
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.372758470313
# , right_weighted_mistakes =  0.0397397786025 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.319358113036
# , right_weighted_mistakes =  0.13328871578 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.350864802539
# , right_weighted_mistakes =  0.112354117995 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.394666111252
# , right_weighted_mistakes =  0.0685528092819 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.432261897467
# , right_weighted_mistakes =  0.0309570230666 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.449433198937
# , right_weighted_mistakes =  0.0137857215967 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.459970929659
# , right_weighted_mistakes =  0.00324799087463 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.10261229691
# , right_weighted_mistakes =  0.360606623624 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.360606623624
# , right_weighted_mistakes =  0.10261229691 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.228740890492
# , right_weighted_mistakes =  0.227975493053 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.462560002081
# , right_weighted_mistakes =  0.000658918452689 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.4259705842
# , right_weighted_mistakes =  0.0372483363343 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.272385284828
# , right_weighted_mistakes =  0.190833635705 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.431182572131
# , right_weighted_mistakes =  0.0320363484026 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.331132466723
# , right_weighted_mistakes =  0.132086453811 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.417566375239
# , right_weighted_mistakes =  0.0456525452951 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.423642176505
# , right_weighted_mistakes =  0.0395767440292 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.428607098501
# , right_weighted_mistakes =  0.0346118220323 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.427510581569
# , right_weighted_mistakes =  0.0357083389644 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.435528225255
# , right_weighted_mistakes =  0.0276906952787 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.438833283705
# , right_weighted_mistakes =  0.0243856368284 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.443222330146
# , right_weighted_mistakes =  0.0199965903877 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.446579414705
# , right_weighted_mistakes =  0.0166395058291 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.421818748639
# , right_weighted_mistakes =  0.0414001718952 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.449784852754
# , right_weighted_mistakes =  0.0134340677801 , sum of data_weights =  1.0
# Split on feature grade.A. (32094, 5130)
# --------------------------------------------------------------------
# Subtree, depth = 2 (32094 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (5130 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.412498248915
# weights =  0.176823632936
# total_alpha =  0.984567810884
# after adjusting, the correct data weights =  [1.9765462704711265e-05, 1.9765462704711265e-05, 1.9765462704711265e-05, 2.711249739214583e-05, 2.711249739214583e-05]
# after adjusting, the wrong data weights =  [3.861504803006748e-05, 3.861504803006748e-05, 3.861504803006748e-05, 3.861504803006748e-05, 3.861504803006748e-05]
# =====================================================
# Adaboost Iteration 2
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.423012612257
# , right_weighted_mistakes =  0.0481696330918 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.354440278048
# , right_weighted_mistakes =  0.113436866813 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.347326249425
# , right_weighted_mistakes =  0.123855995924 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.370479997286
# , right_weighted_mistakes =  0.0830946670224 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.419693276711
# , right_weighted_mistakes =  0.0375238236139 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.444638658296
# , right_weighted_mistakes =  0.0167100365067 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.464197299581
# , right_weighted_mistakes =  0.00393697534859 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.118959343651
# , right_weighted_mistakes =  0.352222901697 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.352222901697
# , right_weighted_mistakes =  0.118959343651 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.263221808566
# , right_weighted_mistakes =  0.200931475172 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.470290724453
# , right_weighted_mistakes =  0.000731608014279 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.431119697324
# , right_weighted_mistakes =  0.0400625480244 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.241885544092
# , right_weighted_mistakes =  0.220272115572 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.437820341114
# , right_weighted_mistakes =  0.0333619042349 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.344733413664
# , right_weighted_mistakes =  0.126448831685 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.427106553999
# , right_weighted_mistakes =  0.0440756913495 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.43239066612
# , right_weighted_mistakes =  0.0387915792291 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.439937459687
# , right_weighted_mistakes =  0.0312447856615 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.43447996131
# , right_weighted_mistakes =  0.0367022840383 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.440924041763
# , right_weighted_mistakes =  0.0302582035858 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.444615497179
# , right_weighted_mistakes =  0.0265667481696 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.450713676796
# , right_weighted_mistakes =  0.0204685685531 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.454590095028
# , right_weighted_mistakes =  0.0165921503204 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.428283228198
# , right_weighted_mistakes =  0.0428990171509 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.447409763978
# , right_weighted_mistakes =  0.0150731512715 , sum of data_weights =  0.999999999999
# Split on feature grade.D. (30465, 6759)
# --------------------------------------------------------------------
# Subtree, depth = 2 (30465 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (6759 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.453574664309
# weights =  0.0931188897111
# total_alpha =  0.995680045408
# after adjusting, the correct data weights =  [1.808615140411088e-05, 2.480896805218879e-05, 1.808615140411088e-05, 2.480896805218879e-05, 2.480896805218879e-05]
# after adjusting, the wrong data weights =  [2.1788543607079363e-05, 2.1788543607079363e-05, 2.1788543607079363e-05, 2.9887579185524787e-05, 2.9887579185524787e-05]
# =====================================================
# Adaboost Iteration 3
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.429006980451
# , right_weighted_mistakes =  0.0531000041253 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.339891338754
# , right_weighted_mistakes =  0.125047622518 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.36401343196
# , right_weighted_mistakes =  0.124616648349 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.407853606445
# , right_weighted_mistakes =  0.0915997668753 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.443787538608
# , right_weighted_mistakes =  0.0343357281983 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.471286188276
# , right_weighted_mistakes =  0.0152903200266 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.492846741394
# , right_weighted_mistakes =  0.00360248243579 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.118388642714
# , right_weighted_mistakes =  0.374353971438 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.374353971438
# , right_weighted_mistakes =  0.118388642714 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.249136487041
# , right_weighted_mistakes =  0.21448348894 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.498768104688
# , right_weighted_mistakes =  0.000685268632486 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.458098295345
# , right_weighted_mistakes =  0.0397587760626 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.257875339533
# , right_weighted_mistakes =  0.208692442346 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.465015718467
# , right_weighted_mistakes =  0.0344376548535 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.356800080746
# , right_weighted_mistakes =  0.134318446442 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.450092540593
# , right_weighted_mistakes =  0.0467845246903 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.456703899109
# , right_weighted_mistakes =  0.0411623763639 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.462429127829
# , right_weighted_mistakes =  0.0332150191342 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.46082022649
# , right_weighted_mistakes =  0.0386331468305 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.468446987233
# , right_weighted_mistakes =  0.0297680894429 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.472317592185
# , right_weighted_mistakes =  0.0266388998388 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.477720209417
# , right_weighted_mistakes =  0.0217186051729 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.481504323336
# , right_weighted_mistakes =  0.0176545917188 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.45496727521
# , right_weighted_mistakes =  0.0442834628411 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.475210187122
# , right_weighted_mistakes =  0.0142220606219 , sum of data_weights =  1.0
# Split on feature home_ownership.MORTGAGE. (19846, 17378)
# --------------------------------------------------------------------
# Subtree, depth = 2 (19846 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (17378 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.463619975981
# weights =  0.0728888552592
# total_alpha =  0.997349475064
# after adjusting, the correct data weights =  [2.0310733650949806e-05, 2.0310733650949806e-05, 2.0310733650949806e-05, 2.7860451403077302e-05, 2.7860451403077302e-05]
# after adjusting, the wrong data weights =  [3.223284234278569e-05, 1.950536251791187e-05, 3.223284234278569e-05, 3.223284234278569e-05, 3.223284234278569e-05]
# =====================================================
# Adaboost Iteration 4
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.431926465926
# , right_weighted_mistakes =  0.0532397041028 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.341632231406
# , right_weighted_mistakes =  0.124886412614 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.362180590228
# , right_weighted_mistakes =  0.125456516183 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.407065544636
# , right_weighted_mistakes =  0.090909234083 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.441644923856
# , right_weighted_mistakes =  0.0345523981407 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.468884872526
# , right_weighted_mistakes =  0.0154132501644 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.490249300346
# , right_weighted_mistakes =  0.00359699336459 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.117111894965
# , right_weighted_mistakes =  0.37060855122 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.37060855122
# , right_weighted_mistakes =  0.117111894965 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.266660879348
# , right_weighted_mistakes =  0.23131389937 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.49709525374
# , right_weighted_mistakes =  0.000739041313994 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.458405509326
# , right_weighted_mistakes =  0.0395692693926 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.271762693742
# , right_weighted_mistakes =  0.225068432291 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.463347223844
# , right_weighted_mistakes =  0.0346275548744 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.361709500067
# , right_weighted_mistakes =  0.136192149464 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.451557519859
# , right_weighted_mistakes =  0.0459731618524 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.457414880515
# , right_weighted_mistakes =  0.0405598982032 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.46448393714
# , right_weighted_mistakes =  0.0327394593598 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.459242079293
# , right_weighted_mistakes =  0.0387326994254 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.466038080724
# , right_weighted_mistakes =  0.0299665147239 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.469776454369
# , right_weighted_mistakes =  0.0265697919317 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.476253770578
# , right_weighted_mistakes =  0.021644253557 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.480232468279
# , right_weighted_mistakes =  0.0177423104399 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.453554315583
# , right_weighted_mistakes =  0.0444204631353 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.472843727239
# , right_weighted_mistakes =  0.0143732281001 , sum of data_weights =  1.0
# Split on feature grade.B. (26858, 10366)
# --------------------------------------------------------------------
# Subtree, depth = 2 (26858 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (10366 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.46651864402
# weights =  0.0670630691411
# total_alpha =  0.997755478666
# after adjusting, the correct data weights =  [1.9036029491248065e-05, 1.9036029491248065e-05, 2.6111926022114015e-05, 2.6111926022114015e-05, 2.6111926022114015e-05]
# after adjusting, the wrong data weights =  [2.176840509089053e-05, 2.9859954966663394e-05, 2.9859954966663394e-05, 2.9859954966663394e-05, 3.454614596434116e-05]
# =====================================================
# Adaboost Iteration 5
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.433624246868
# , right_weighted_mistakes =  0.0498983736788 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.349673294036
# , right_weighted_mistakes =  0.133849326511 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.356250892146
# , right_weighted_mistakes =  0.127271728401 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.398318861255
# , right_weighted_mistakes =  0.0852037592916 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.430728034353
# , right_weighted_mistakes =  0.0370321728656 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.45625840047
# , right_weighted_mistakes =  0.0165194364277 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.476281994154
# , right_weighted_mistakes =  0.00385514428062 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.121127126266
# , right_weighted_mistakes =  0.362395494281 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.362395494281
# , right_weighted_mistakes =  0.121127126266 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.258474643216
# , right_weighted_mistakes =  0.225047977331 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.482657066346
# , right_weighted_mistakes =  0.000769657528585 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.445232230958
# , right_weighted_mistakes =  0.0382903895891 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.26420392112
# , right_weighted_mistakes =  0.219318699427 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.44995141557
# , right_weighted_mistakes =  0.0335712049773 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.351340649784
# , right_weighted_mistakes =  0.132181970763 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.438960461166
# , right_weighted_mistakes =  0.0445621593808 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.444148825036
# , right_weighted_mistakes =  0.0393737955113 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.451702504038
# , right_weighted_mistakes =  0.0318201165091 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.445894019111
# , right_weighted_mistakes =  0.0376286014357 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.452465339891
# , right_weighted_mistakes =  0.0307957512525 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.456150161733
# , right_weighted_mistakes =  0.0273724588143 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.462408167
# , right_weighted_mistakes =  0.0211144535474 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.466326800751
# , right_weighted_mistakes =  0.0171958197957 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.440359452221
# , right_weighted_mistakes =  0.0431631683264 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.459041029718
# , right_weighted_mistakes =  0.0147615893718 , sum of data_weights =  1.0
# Split on feature grade.E. (33815, 3409)
# --------------------------------------------------------------------
# Subtree, depth = 2 (33815 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (3409 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.467760207218
# weights =  0.0645691696164
# total_alpha =  0.997919026297
# after adjusting, the correct data weights =  [1.7882944632678302e-05, 1.7882944632678302e-05, 1.7882944632678302e-05, 2.4530227142206503e-05, 1.7882944632678302e-05]
# after adjusting, the wrong data weights =  [2.0348064240497852e-05, 2.0348064240497852e-05, 2.3268765443248954e-05, 2.791165817353795e-05, 3.191801536971688e-05]
# =====================================================
# Adaboost Iteration 6
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.41940920145
# , right_weighted_mistakes =  0.0533375572663 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.348767108168
# , right_weighted_mistakes =  0.141220844442 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.363672382638
# , right_weighted_mistakes =  0.126315569972 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.396840149776
# , right_weighted_mistakes =  0.0910763228432 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.450403383108
# , right_weighted_mistakes =  0.0395845695018 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.474469161407
# , right_weighted_mistakes =  0.0155187912025 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.486366329111
# , right_weighted_mistakes =  0.00362162349838 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.11893549139
# , right_weighted_mistakes =  0.37105246122 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.37105246122
# , right_weighted_mistakes =  0.11893549139 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.262273476349
# , right_weighted_mistakes =  0.227714476261 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.489257204763
# , right_weighted_mistakes =  0.000730747847087 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.448059745532
# , right_weighted_mistakes =  0.0404139647516 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.270373431186
# , right_weighted_mistakes =  0.219614521424 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.45549592414
# , right_weighted_mistakes =  0.0344920284701 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.352644794999
# , right_weighted_mistakes =  0.137343157611 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.440750825736
# , right_weighted_mistakes =  0.0469405781931 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.44774473413
# , right_weighted_mistakes =  0.0415100228384 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.4534202964
# , right_weighted_mistakes =  0.0335090470664 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.452133295463
# , right_weighted_mistakes =  0.0378546571471 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.460840283205
# , right_weighted_mistakes =  0.0291476694048 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.463953279521
# , right_weighted_mistakes =  0.0260346730886 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.468946206846
# , right_weighted_mistakes =  0.0210417457642 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.472523453968
# , right_weighted_mistakes =  0.0174644986422 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.445419474866
# , right_weighted_mistakes =  0.0445684777438 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.475994909436
# , right_weighted_mistakes =  0.0139930431742 , sum of data_weights =  1.0
# Split on feature grade.A. (32094, 5130)
# --------------------------------------------------------------------
# Subtree, depth = 2 (32094 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (5130 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.472746758716
# weights =  0.0545605577919
# total_alpha =  0.998513416714
# after adjusting, the correct data weights =  [1.9296291276426382e-05, 1.9296291276426382e-05, 2.2066024086072514e-05, 2.6468929906988432e-05, 3.026820213756323e-05]
# after adjusting, the wrong data weights =  [4.2044978849654936e-05, 4.2044978849654936e-05, 4.2044978849654936e-05, 4.2044978849654936e-05, 4.8643475116738265e-05]
# =====================================================
# Adaboost Iteration 7
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.4330694004
# , right_weighted_mistakes =  0.0564123986922 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.353802476223
# , right_weighted_mistakes =  0.13567932287 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.360470003665
# , right_weighted_mistakes =  0.129011795428 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.403113128678
# , right_weighted_mistakes =  0.0863686704149 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.442448786293
# , right_weighted_mistakes =  0.0418665689103 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.461844820895
# , right_weighted_mistakes =  0.0164134295121 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.482142178403
# , right_weighted_mistakes =  0.0038304054249 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.119120223939
# , right_weighted_mistakes =  0.370361575153 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.370361575153
# , right_weighted_mistakes =  0.119120223939 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.261238085422
# , right_weighted_mistakes =  0.228243713671 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.488615228739
# , right_weighted_mistakes =  0.000755696304149 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.450673517238
# ...
# , right_weighted_mistakes =  0.13378977321 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.444438096481
# , right_weighted_mistakes =  0.0450437026115 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.449655078184
# , right_weighted_mistakes =  0.0398267209085 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.457335678321
# , right_weighted_mistakes =  0.0321461207714 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.451334878706
# , right_weighted_mistakes =  0.0381469203865 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.458085513207
# , right_weighted_mistakes =  0.0303708683263 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.461798774434
# , right_weighted_mistakes =  0.0272069898284 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.468129943629
# , right_weighted_mistakes =  0.0213518554637 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.472117572908
# , right_weighted_mistakes =  0.0173642261849 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.445789293946
# , right_weighted_mistakes =  0.0436925051468 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.464461173831
# , right_weighted_mistakes =  0.0145087594245 , sum of data_weights =  1.0
# Split on feature grade.F. (35512, 1712)
# --------------------------------------------------------------------
# Subtree, depth = 2 (35512 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (1712 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.478258250407
# weights =  0.0435109367337
# total_alpha =  0.999054145329
# after adjusting, the correct data weights =  [1.849218630814562e-05, 1.849218630814562e-05, 2.1394331241095437e-05, 2.934683385087885e-05, 2.1394331241095437e-05]
# after adjusting, the wrong data weights =  [2.0173505903985677e-05, 2.306915151730205e-05, 2.7672214629302804e-05, 3.164420280445974e-05, 3.164420280445974e-05]
# =====================================================
# Adaboost Iteration 8
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.426532781359
# , right_weighted_mistakes =  0.0589769216153 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.347536376951
# , right_weighted_mistakes =  0.141847341635 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.362643989426
# , right_weighted_mistakes =  0.128030294555 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.396262006566
# , right_weighted_mistakes =  0.0902950135637 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.450552356856
# , right_weighted_mistakes =  0.0401219271248 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.473514695518
# , right_weighted_mistakes =  0.017159588463 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.48700349721
# , right_weighted_mistakes =  0.00367078677132 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.121554040749
# , right_weighted_mistakes =  0.369120243232 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.369120243232
# , right_weighted_mistakes =  0.121554040749 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.263181621993
# , right_weighted_mistakes =  0.227492661988 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.489946542879
# , right_weighted_mistakes =  0.00072774110195 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.44878376293
# , right_weighted_mistakes =  0.0403746852638 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.270110924141
# , right_weighted_mistakes =  0.22056335984 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.456148402656
# , right_weighted_mistakes =  0.0345258813253 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.353082892697
# , right_weighted_mistakes =  0.137591391284 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.441318484517
# , right_weighted_mistakes =  0.0468797881183 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.448354826302
# , right_weighted_mistakes =  0.0414483973759 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.454129018409
# , right_weighted_mistakes =  0.0334440058938 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.452741147067
# , right_weighted_mistakes =  0.0379331369143 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.46148169778
# , right_weighted_mistakes =  0.029192586201 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.464512114402
# , right_weighted_mistakes =  0.0261621695787 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.469579797367
# , right_weighted_mistakes =  0.0210944866138 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.473218493425
# , right_weighted_mistakes =  0.0174557905566 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.446108901733
# , right_weighted_mistakes =  0.0445653822482 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.476741347436
# , right_weighted_mistakes =  0.0139329365446 , sum of data_weights =  1.0
# Split on feature grade.A. (32094, 5130)
# --------------------------------------------------------------------
# Subtree, depth = 2 (32094 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (5130 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.485509702974
# weights =  0.0289887115005
# total_alpha =  0.999579974373
# after adjusting, the correct data weights =  [1.9605331743468826e-05, 1.7971365461151638e-05, 2.2419423311428347e-05, 2.6892844033459073e-05, 3.0752963649043686e-05]
# after adjusting, the wrong data weights =  [4.526825592385536e-05, 4.526825592385536e-05, 4.526825592385536e-05, 4.526825592385536e-05, 5.2372610020429806e-05]
# =====================================================
# Adaboost Iteration 9
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.437665002631
# , right_weighted_mistakes =  0.060737119417 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.35418794345
# , right_weighted_mistakes =  0.137852300087 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.367324133436
# , right_weighted_mistakes =  0.131077988612 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.404367815569
# , right_weighted_mistakes =  0.0877519110522 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.450615850292
# , right_weighted_mistakes =  0.041319387521 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.472662759581
# , right_weighted_mistakes =  0.0176717255679 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.490944953392
# , right_weighted_mistakes =  0.00378034336784 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.119355793638
# , right_weighted_mistakes =  0.376495952503 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.376495952503
# , right_weighted_mistakes =  0.119355793638 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.265806491209
# , right_weighted_mistakes =  0.232295076412 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.497523605859
# , right_weighted_mistakes =  0.000741178165833 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.458819070482
# , right_weighted_mistakes =  0.0395210738586 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.272995220887
# , right_weighted_mistakes =  0.225406901161 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.463760902346
# , right_weighted_mistakes =  0.0346412197027 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.36092104773
# , right_weighted_mistakes =  0.136179888608 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.451126522215
# , right_weighted_mistakes =  0.0458700456333 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.457849875548
# , right_weighted_mistakes =  0.0405522465005 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.464264593042
# , right_weighted_mistakes =  0.0327186250032 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.459553111689
# , right_weighted_mistakes =  0.0387843724894 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.466488436695
# , right_weighted_mistakes =  0.0298434434248 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.4702276114
# , right_weighted_mistakes =  0.0267845784167 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.476671383021
# , right_weighted_mistakes =  0.0215789160332 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.480743986473
# , right_weighted_mistakes =  0.0176581355753 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.45387704651
# , right_weighted_mistakes =  0.0445250755388 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.472813181951
# , right_weighted_mistakes =  0.0142084790974 , sum of data_weights =  1.0
# Split on feature emp_length.n/a. (35781, 1443)
# --------------------------------------------------------------------
# Subtree, depth = 2 (35781 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (1443 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.487021661048
# weights =  0.0259625096916
# total_alpha =  0.999663068675
# after adjusting, the correct data weights =  [4.4122970198240284e-05, 2.6212455762160944e-05, 5.1047584316534856e-05, 2.517306666082776e-05, 2.6212455762160944e-05]
# after adjusting, the wrong data weights =  [2.0127782100372667e-05, 1.845027326144203e-05, 2.301686465360487e-05, 2.7609494797000504e-05, 3.157248035217961e-05]

# %% [markdown]
# ## Making predictions
#
# Recall from the lecture that in order to make predictions, we use the following formula:
# $$
# \hat{y} = sign\left(\sum_{t=1}^T \hat{w}_t f_t(x)\right)
# $$
#
# We need to do the following things:
# - Compute the predictions $f_t(x)$ using the $t$-th decision tree
# - Compute $\hat{w}_t f_t(x)$ by multiplying the `stump_weights` with the predictions $f_t(x)$ from the decision trees
# - Sum the weighted predictions over each stump in the ensemble.
#
# Complete the following skeleton for making predictions:

# %%
def predict_adaboost(stump_weights, tree_stumps, data):
    scores = graphlab.SArray([0.]*len(data))
    
    for i, tree_stump in enumerate(tree_stumps):
        predictions = data.apply(lambda x: classify(tree_stump, x))
        
        # Accumulate predictions on scores array
        # YOUR CODE HERE
        scores += stump_weights[i] * predictions
        
    return scores.apply(lambda score : +1 if score > 0 else -1)

# %%
predictions = predict_adaboost(stump_weights, tree_stumps, test_data)
accuracy = graphlab.evaluation.accuracy(test_data[target], predictions)
print 'Accuracy of 10-component ensemble = %s' % accuracy
# Out:
# Accuracy of 10-component ensemble = 0.620314519604

# %% [markdown]
# Now, let us take a quick look what the `stump_weights` look like at the end of each iteration of the 10-stump ensemble:

# %%
stump_weights
# Out:
# [0.15802933659263743,
#  0.17682363293639866,
#  0.09311888971113731,
#  0.07288885525917756,
#  0.06706306914108065,
#  0.06456916961640516,
#  0.05456055779189783,
#  0.043510936733701114,
#  0.0289887115005497,
#  0.025962509691571333]

# %% [markdown]
# **Quiz Question:** Are the weights monotonically decreasing, monotonically increasing, or neither?
#
# **Reminder**: Stump weights ($\mathbf{\hat{w}}$) tell you how important each stump is while making predictions with the entire boosted ensemble.

# %% [markdown]
# # Performance plots
#
# In this section, we will try to reproduce some of the performance plots dicussed in the lecture.
#
# ### How does accuracy change with adding stumps to the ensemble?
#
# We will now train an ensemble with:
# * `train_data`
# * `features`
# * `target`
# * `num_tree_stumps = 30`
#
# Once we are done with this, we will then do the following:
# * Compute the classification error at the end of each iteration.
# * Plot a curve of classification error vs iteration.
#
# First, lets train the model.

# %%
# this may take a while... 
stump_weights, tree_stumps = adaboost_with_tree_stumps(train_data, 
                                 features, target, num_tree_stumps=30)
# Out:
# =====================================================
# Adaboost Iteration 0
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  14876.0
# , right_weighted_mistakes =  1258.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  12725.0
# , right_weighted_mistakes =  4343.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  13562.0
# , right_weighted_mistakes =  4498.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  14400.0
# , right_weighted_mistakes =  2683.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  16168.0
# , right_weighted_mistakes =  1101.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  17226.0
# , right_weighted_mistakes =  462.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  18149.0
# , right_weighted_mistakes =  109.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  3221.0
# , right_weighted_mistakes =  12474.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  12474.0
# , right_weighted_mistakes =  3221.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  9383.0
# , right_weighted_mistakes =  8013.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  18443.0
# , right_weighted_mistakes =  28.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  16916.0
# , right_weighted_mistakes =  1515.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  9606.0
# , right_weighted_mistakes =  7840.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  17190.0
# , right_weighted_mistakes =  1286.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  13417.0
# , right_weighted_mistakes =  5059.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  16766.0
# , right_weighted_mistakes =  1710.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  16967.0
# , right_weighted_mistakes =  1509.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  17258.0
# , right_weighted_mistakes =  1218.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  17041.0
# , right_weighted_mistakes =  1435.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  17285.0
# , right_weighted_mistakes =  1128.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  17427.0
# , right_weighted_mistakes =  979.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  17665.0
# , right_weighted_mistakes =  806.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  17811.0
# , right_weighted_mistakes =  665.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  16818.0
# , right_weighted_mistakes =  1658.0 , sum of data_weights =  37224.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  17591.0
# , right_weighted_mistakes =  558.0 , sum of data_weights =  37224.0
# Split on feature term. 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9223 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (28001 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.421636578551
# weights =  0.158029336593
# total_alpha =  36763.9853661
# after adjusting, the correct data weights =  [2.3224487900041803e-05, 2.3224487900041803e-05, 2.3224487900041803e-05, 2.3224487900041803e-05, 2.3224487900041803e-05]
# after adjusting, the wrong data weights =  [3.185727938834023e-05, 3.185727938834023e-05, 3.185727938834023e-05, 3.185727938834023e-05, 3.185727938834023e-05]
# =====================================================
# Adaboost Iteration 1
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.372758470313
# , right_weighted_mistakes =  0.0397397786025 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.319358113036
# , right_weighted_mistakes =  0.13328871578 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.350864802539
# , right_weighted_mistakes =  0.112354117995 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.394666111252
# , right_weighted_mistakes =  0.0685528092819 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.432261897467
# , right_weighted_mistakes =  0.0309570230666 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.449433198937
# , right_weighted_mistakes =  0.0137857215967 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.459970929659
# , right_weighted_mistakes =  0.00324799087463 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.10261229691
# , right_weighted_mistakes =  0.360606623624 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.360606623624
# , right_weighted_mistakes =  0.10261229691 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.228740890492
# , right_weighted_mistakes =  0.227975493053 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.462560002081
# , right_weighted_mistakes =  0.000658918452689 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.4259705842
# , right_weighted_mistakes =  0.0372483363343 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.272385284828
# , right_weighted_mistakes =  0.190833635705 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.431182572131
# , right_weighted_mistakes =  0.0320363484026 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.331132466723
# , right_weighted_mistakes =  0.132086453811 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.417566375239
# , right_weighted_mistakes =  0.0456525452951 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.423642176505
# , right_weighted_mistakes =  0.0395767440292 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.428607098501
# , right_weighted_mistakes =  0.0346118220323 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.427510581569
# , right_weighted_mistakes =  0.0357083389644 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.435528225255
# , right_weighted_mistakes =  0.0276906952787 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.438833283705
# , right_weighted_mistakes =  0.0243856368284 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.443222330146
# , right_weighted_mistakes =  0.0199965903877 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.446579414705
# , right_weighted_mistakes =  0.0166395058291 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.421818748639
# , right_weighted_mistakes =  0.0414001718952 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.449784852754
# , right_weighted_mistakes =  0.0134340677801 , sum of data_weights =  1.0
# Split on feature grade.A. (32094, 5130)
# --------------------------------------------------------------------
# Subtree, depth = 2 (32094 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (5130 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.412498248915
# weights =  0.176823632936
# total_alpha =  0.984567810884
# after adjusting, the correct data weights =  [1.9765462704711265e-05, 1.9765462704711265e-05, 1.9765462704711265e-05, 2.711249739214583e-05, 2.711249739214583e-05]
# after adjusting, the wrong data weights =  [3.861504803006748e-05, 3.861504803006748e-05, 3.861504803006748e-05, 3.861504803006748e-05, 3.861504803006748e-05]
# =====================================================
# Adaboost Iteration 2
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.423012612257
# , right_weighted_mistakes =  0.0481696330918 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.354440278048
# , right_weighted_mistakes =  0.113436866813 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.347326249425
# , right_weighted_mistakes =  0.123855995924 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.370479997286
# , right_weighted_mistakes =  0.0830946670224 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.419693276711
# , right_weighted_mistakes =  0.0375238236139 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.444638658296
# , right_weighted_mistakes =  0.0167100365067 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.464197299581
# , right_weighted_mistakes =  0.00393697534859 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.118959343651
# , right_weighted_mistakes =  0.352222901697 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.352222901697
# , right_weighted_mistakes =  0.118959343651 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.263221808566
# , right_weighted_mistakes =  0.200931475172 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.470290724453
# , right_weighted_mistakes =  0.000731608014279 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.431119697324
# , right_weighted_mistakes =  0.0400625480244 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.241885544092
# , right_weighted_mistakes =  0.220272115572 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.437820341114
# , right_weighted_mistakes =  0.0333619042349 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.344733413664
# , right_weighted_mistakes =  0.126448831685 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.427106553999
# , right_weighted_mistakes =  0.0440756913495 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.43239066612
# , right_weighted_mistakes =  0.0387915792291 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.439937459687
# , right_weighted_mistakes =  0.0312447856615 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.43447996131
# , right_weighted_mistakes =  0.0367022840383 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.440924041763
# , right_weighted_mistakes =  0.0302582035858 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.444615497179
# , right_weighted_mistakes =  0.0265667481696 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.450713676796
# , right_weighted_mistakes =  0.0204685685531 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.454590095028
# , right_weighted_mistakes =  0.0165921503204 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.428283228198
# , right_weighted_mistakes =  0.0428990171509 , sum of data_weights =  0.999999999999
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.447409763978
# , right_weighted_mistakes =  0.0150731512715 , sum of data_weights =  0.999999999999
# Split on feature grade.D. (30465, 6759)
# --------------------------------------------------------------------
# Subtree, depth = 2 (30465 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (6759 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.453574664309
# weights =  0.0931188897111
# total_alpha =  0.995680045408
# after adjusting, the correct data weights =  [1.808615140411088e-05, 2.480896805218879e-05, 1.808615140411088e-05, 2.480896805218879e-05, 2.480896805218879e-05]
# after adjusting, the wrong data weights =  [2.1788543607079363e-05, 2.1788543607079363e-05, 2.1788543607079363e-05, 2.9887579185524787e-05, 2.9887579185524787e-05]
# =====================================================
# Adaboost Iteration 3
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.429006980451
# , right_weighted_mistakes =  0.0531000041253 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.339891338754
# , right_weighted_mistakes =  0.125047622518 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.36401343196
# , right_weighted_mistakes =  0.124616648349 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.407853606445
# , right_weighted_mistakes =  0.0915997668753 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.443787538608
# , right_weighted_mistakes =  0.0343357281983 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.471286188276
# , right_weighted_mistakes =  0.0152903200266 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.492846741394
# , right_weighted_mistakes =  0.00360248243579 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.118388642714
# , right_weighted_mistakes =  0.374353971438 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.374353971438
# , right_weighted_mistakes =  0.118388642714 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.249136487041
# , right_weighted_mistakes =  0.21448348894 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.498768104688
# , right_weighted_mistakes =  0.000685268632486 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.458098295345
# , right_weighted_mistakes =  0.0397587760626 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.257875339533
# , right_weighted_mistakes =  0.208692442346 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.465015718467
# , right_weighted_mistakes =  0.0344376548535 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.356800080746
# , right_weighted_mistakes =  0.134318446442 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.450092540593
# , right_weighted_mistakes =  0.0467845246903 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.456703899109
# , right_weighted_mistakes =  0.0411623763639 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.462429127829
# , right_weighted_mistakes =  0.0332150191342 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.46082022649
# , right_weighted_mistakes =  0.0386331468305 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.468446987233
# , right_weighted_mistakes =  0.0297680894429 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.472317592185
# , right_weighted_mistakes =  0.0266388998388 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.477720209417
# , right_weighted_mistakes =  0.0217186051729 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.481504323336
# , right_weighted_mistakes =  0.0176545917188 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.45496727521
# , right_weighted_mistakes =  0.0442834628411 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.475210187122
# , right_weighted_mistakes =  0.0142220606219 , sum of data_weights =  1.0
# Split on feature home_ownership.MORTGAGE. (19846, 17378)
# --------------------------------------------------------------------
# Subtree, depth = 2 (19846 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (17378 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.463619975981
# weights =  0.0728888552592
# total_alpha =  0.997349475064
# after adjusting, the correct data weights =  [2.0310733650949806e-05, 2.0310733650949806e-05, 2.0310733650949806e-05, 2.7860451403077302e-05, 2.7860451403077302e-05]
# after adjusting, the wrong data weights =  [3.223284234278569e-05, 1.950536251791187e-05, 3.223284234278569e-05, 3.223284234278569e-05, 3.223284234278569e-05]
# =====================================================
# Adaboost Iteration 4
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.431926465926
# , right_weighted_mistakes =  0.0532397041028 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.341632231406
# , right_weighted_mistakes =  0.124886412614 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.362180590228
# , right_weighted_mistakes =  0.125456516183 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.407065544636
# , right_weighted_mistakes =  0.090909234083 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.441644923856
# , right_weighted_mistakes =  0.0345523981407 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.468884872526
# , right_weighted_mistakes =  0.0154132501644 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.490249300346
# , right_weighted_mistakes =  0.00359699336459 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.117111894965
# , right_weighted_mistakes =  0.37060855122 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.37060855122
# , right_weighted_mistakes =  0.117111894965 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.266660879348
# , right_weighted_mistakes =  0.23131389937 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.49709525374
# , right_weighted_mistakes =  0.000739041313994 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.458405509326
# , right_weighted_mistakes =  0.0395692693926 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.271762693742
# , right_weighted_mistakes =  0.225068432291 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.463347223844
# , right_weighted_mistakes =  0.0346275548744 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.361709500067
# , right_weighted_mistakes =  0.136192149464 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.451557519859
# , right_weighted_mistakes =  0.0459731618524 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.457414880515
# , right_weighted_mistakes =  0.0405598982032 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.46448393714
# , right_weighted_mistakes =  0.0327394593598 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.459242079293
# , right_weighted_mistakes =  0.0387326994254 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.466038080724
# , right_weighted_mistakes =  0.0299665147239 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.469776454369
# , right_weighted_mistakes =  0.0265697919317 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.476253770578
# , right_weighted_mistakes =  0.021644253557 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.480232468279
# , right_weighted_mistakes =  0.0177423104399 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.453554315583
# , right_weighted_mistakes =  0.0444204631353 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.472843727239
# , right_weighted_mistakes =  0.0143732281001 , sum of data_weights =  1.0
# Split on feature grade.B. (26858, 10366)
# --------------------------------------------------------------------
# Subtree, depth = 2 (26858 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (10366 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.46651864402
# weights =  0.0670630691411
# total_alpha =  0.997755478666
# after adjusting, the correct data weights =  [1.9036029491248065e-05, 1.9036029491248065e-05, 2.6111926022114015e-05, 2.6111926022114015e-05, 2.6111926022114015e-05]
# after adjusting, the wrong data weights =  [2.176840509089053e-05, 2.9859954966663394e-05, 2.9859954966663394e-05, 2.9859954966663394e-05, 3.454614596434116e-05]
# =====================================================
# Adaboost Iteration 5
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.433624246868
# , right_weighted_mistakes =  0.0498983736788 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.349673294036
# , right_weighted_mistakes =  0.133849326511 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.356250892146
# , right_weighted_mistakes =  0.127271728401 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.398318861255
# , right_weighted_mistakes =  0.0852037592916 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.430728034353
# , right_weighted_mistakes =  0.0370321728656 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.45625840047
# , right_weighted_mistakes =  0.0165194364277 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.476281994154
# , right_weighted_mistakes =  0.00385514428062 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.121127126266
# , right_weighted_mistakes =  0.362395494281 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.362395494281
# , right_weighted_mistakes =  0.121127126266 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.258474643216
# , right_weighted_mistakes =  0.225047977331 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.482657066346
# , right_weighted_mistakes =  0.000769657528585 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.445232230958
# , right_weighted_mistakes =  0.0382903895891 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.26420392112
# , right_weighted_mistakes =  0.219318699427 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.44995141557
# , right_weighted_mistakes =  0.0335712049773 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.351340649784
# , right_weighted_mistakes =  0.132181970763 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.438960461166
# , right_weighted_mistakes =  0.0445621593808 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.444148825036
# , right_weighted_mistakes =  0.0393737955113 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.451702504038
# , right_weighted_mistakes =  0.0318201165091 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.445894019111
# , right_weighted_mistakes =  0.0376286014357 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.452465339891
# , right_weighted_mistakes =  0.0307957512525 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.456150161733
# , right_weighted_mistakes =  0.0273724588143 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.462408167
# , right_weighted_mistakes =  0.0211144535474 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.466326800751
# , right_weighted_mistakes =  0.0171958197957 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.440359452221
# , right_weighted_mistakes =  0.0431631683264 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.459041029718
# , right_weighted_mistakes =  0.0147615893718 , sum of data_weights =  1.0
# Split on feature grade.E. (33815, 3409)
# --------------------------------------------------------------------
# Subtree, depth = 2 (33815 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (3409 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.467760207218
# weights =  0.0645691696164
# total_alpha =  0.997919026297
# after adjusting, the correct data weights =  [1.7882944632678302e-05, 1.7882944632678302e-05, 1.7882944632678302e-05, 2.4530227142206503e-05, 1.7882944632678302e-05]
# after adjusting, the wrong data weights =  [2.0348064240497852e-05, 2.0348064240497852e-05, 2.3268765443248954e-05, 2.791165817353795e-05, 3.191801536971688e-05]
# =====================================================
# Adaboost Iteration 6
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.41940920145
# , right_weighted_mistakes =  0.0533375572663 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.348767108168
# , right_weighted_mistakes =  0.141220844442 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.363672382638
# , right_weighted_mistakes =  0.126315569972 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.396840149776
# , right_weighted_mistakes =  0.0910763228432 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.450403383108
# , right_weighted_mistakes =  0.0395845695018 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.474469161407
# , right_weighted_mistakes =  0.0155187912025 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.486366329111
# , right_weighted_mistakes =  0.00362162349838 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.11893549139
# , right_weighted_mistakes =  0.37105246122 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.37105246122
# , right_weighted_mistakes =  0.11893549139 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.262273476349
# , right_weighted_mistakes =  0.227714476261 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.489257204763
# , right_weighted_mistakes =  0.000730747847087 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.448059745532
# , right_weighted_mistakes =  0.0404139647516 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.270373431186
# , right_weighted_mistakes =  0.219614521424 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.45549592414
# , right_weighted_mistakes =  0.0344920284701 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.352644794999
# , right_weighted_mistakes =  0.137343157611 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.440750825736
# , right_weighted_mistakes =  0.0469405781931 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.44774473413
# , right_weighted_mistakes =  0.0415100228384 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.4534202964
# , right_weighted_mistakes =  0.0335090470664 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.452133295463
# , right_weighted_mistakes =  0.0378546571471 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.460840283205
# , right_weighted_mistakes =  0.0291476694048 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.463953279521
# , right_weighted_mistakes =  0.0260346730886 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.468946206846
# , right_weighted_mistakes =  0.0210417457642 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.472523453968
# , right_weighted_mistakes =  0.0174644986422 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.445419474866
# , right_weighted_mistakes =  0.0445684777438 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.475994909436
# , right_weighted_mistakes =  0.0139930431742 , sum of data_weights =  1.0
# Split on feature grade.A. (32094, 5130)
# --------------------------------------------------------------------
# Subtree, depth = 2 (32094 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (5130 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.472746758716
# weights =  0.0545605577919
# total_alpha =  0.998513416714
# after adjusting, the correct data weights =  [1.9296291276426382e-05, 1.9296291276426382e-05, 2.2066024086072514e-05, 2.6468929906988432e-05, 3.026820213756323e-05]
# after adjusting, the wrong data weights =  [4.2044978849654936e-05, 4.2044978849654936e-05, 4.2044978849654936e-05, 4.2044978849654936e-05, 4.8643475116738265e-05]
# =====================================================
# Adaboost Iteration 7
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.4330694004
# , right_weighted_mistakes =  0.0564123986922 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.353802476223
# , right_weighted_mistakes =  0.13567932287 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.360470003665
# , right_weighted_mistakes =  0.129011795428 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.403113128678
# , right_weighted_mistakes =  0.0863686704149 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.442448786293
# , right_weighted_mistakes =  0.0418665689103 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.461844820895
# , right_weighted_mistakes =  0.0164134295121 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.482142178403
# , right_weighted_mistakes =  0.0038304054249 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.119120223939
# , right_weighted_mistakes =  0.370361575153 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.370361575153
# , right_weighted_mistakes =  0.119120223939 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.261238085422
# , right_weighted_mistakes =  0.228243713671 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.488615228739
# , right_weighted_mistakes =  0.000755696304149 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.450673517238
# ...
# , right_weighted_mistakes =  0.138333311262 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.447845551437
# , right_weighted_mistakes =  0.0478337610597 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.453591354873
# , right_weighted_mistakes =  0.0410944293503 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.461090061825
# , right_weighted_mistakes =  0.0346402064255 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.458129535988
# , right_weighted_mistakes =  0.0383110020277 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.466872722684
# , right_weighted_mistakes =  0.0295678153321 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.46991791249
# , right_weighted_mistakes =  0.0265226255259 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.475140192373
# , right_weighted_mistakes =  0.0213003456434 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.478863209285
# , right_weighted_mistakes =  0.0175773287306 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.451296225972
# , right_weighted_mistakes =  0.0451392458397 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.479199334315
# , right_weighted_mistakes =  0.0172412037011 , sum of data_weights =  1.0
# Split on feature home_ownership.OWN. (34149, 3075)
# --------------------------------------------------------------------
# Subtree, depth = 2 (34149 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (3075 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.493184682982
# weights =  0.0136314782943
# total_alpha =  0.999907098593
# after adjusting, the correct data weights =  [1.996249186353151e-05, 2.3735115230244053e-05, 2.626153491476075e-05, 3.122458666914411e-05, 3.122458666914411e-05]
# after adjusting, the wrong data weights =  [1.7364736649461413e-05, 3.808130462218244e-05, 4.664576899555277e-05, 1.8036621932967815e-05, 2.051421504234658e-05]
# =====================================================
# Adaboost Iteration 28
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.437241628993
# , right_weighted_mistakes =  0.0606241439177 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.356773602468
# , right_weighted_mistakes =  0.140236863535 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.367951316153
# , right_weighted_mistakes =  0.128901368824 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.406088243849
# , right_weighted_mistakes =  0.0917775290614 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.451745026047
# , right_weighted_mistakes =  0.043034825286 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.474916122018
# , right_weighted_mistakes =  0.0198795312689 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.490610303094
# , right_weighted_mistakes =  0.00390658062746 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.120210050218
# , right_weighted_mistakes =  0.377655722693 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.377655722693
# , right_weighted_mistakes =  0.120210050218 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.265707140069
# , right_weighted_mistakes =  0.232158632842 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.496996827001
# , right_weighted_mistakes =  0.000759558848267 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.457789241137
# , right_weighted_mistakes =  0.0400765317739 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.273104110526
# , right_weighted_mistakes =  0.224761662385 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.463222827644
# , right_weighted_mistakes =  0.0346429452671 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.361109493438
# , right_weighted_mistakes =  0.136756279473 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.450582144885
# , right_weighted_mistakes =  0.0472836280257 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.457242227738
# , right_weighted_mistakes =  0.0406235451723 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.463621099637
# , right_weighted_mistakes =  0.0342446732734 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.458920249918
# , right_weighted_mistakes =  0.0387601331569 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.4658823582
# , right_weighted_mistakes =  0.0299192390238 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.469619111093
# , right_weighted_mistakes =  0.0268327416252 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.476046598081
# , right_weighted_mistakes =  0.0215556009649 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.48017631611
# , right_weighted_mistakes =  0.0176894568005 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.453230523071
# , right_weighted_mistakes =  0.04463524984 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.476870552202
# , right_weighted_mistakes =  0.0173821291113 , sum of data_weights =  1.0
# Split on feature emp_length.n/a. (35781, 1443)
# --------------------------------------------------------------------
# Subtree, depth = 2 (35781 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (1443 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.494252681313
# weights =  0.0114951436639
# total_alpha =  0.999933934474
# after adjusting, the correct data weights =  [3.764854821280374e-05, 2.119610598497934e-05, 4.23856197277808e-05, 2.1560897553261596e-05, 2.119610598497934e-05]
# after adjusting, the wrong data weights =  [2.019462171708015e-05, 1.7566659024829494e-05, 2.401111428186656e-05, 2.656691193359188e-05, 3.158767554503072e-05]
# =====================================================
# Adaboost Iteration 29
# =====================================================
# --------------------------------------------------------------------
# Subtree, depth = 1 (37224 data points).
# inside best_splitting_feature():, the current feature is:  grade.A
# inside best_feature_split(): left_weighted_mistakes =  0.434944354249
# , right_weighted_mistakes =  0.0612455705201 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.B
# inside best_feature_split(): left_weighted_mistakes =  0.352997205189
# , right_weighted_mistakes =  0.141721451806 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.C
# inside best_feature_split(): left_weighted_mistakes =  0.364076968443
# , right_weighted_mistakes =  0.130271485598 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.D
# inside best_feature_split(): left_weighted_mistakes =  0.404572362474
# , right_weighted_mistakes =  0.0922552604917 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.E
# inside best_feature_split(): left_weighted_mistakes =  0.454250024798
# , right_weighted_mistakes =  0.042577598168 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.F
# inside best_feature_split(): left_weighted_mistakes =  0.477162645207
# , right_weighted_mistakes =  0.0196649777591 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  grade.G
# inside best_feature_split(): left_weighted_mistakes =  0.492962177437
# , right_weighted_mistakes =  0.00386544552941 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 36 months
# inside best_feature_split(): left_weighted_mistakes =  0.121541930891
# , right_weighted_mistakes =  0.374242554204 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  term. 60 months
# inside best_feature_split(): left_weighted_mistakes =  0.374242554204
# , right_weighted_mistakes =  0.121541930891 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.MORTGAGE
# inside best_feature_split(): left_weighted_mistakes =  0.266642085144
# , right_weighted_mistakes =  0.230185537822 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OTHER
# inside best_feature_split(): left_weighted_mistakes =  0.496075847674
# , right_weighted_mistakes =  0.000751775292357 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.OWN
# inside best_feature_split(): left_weighted_mistakes =  0.455015577321
# , right_weighted_mistakes =  0.0404674159633 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  home_ownership.RENT
# inside best_feature_split(): left_weighted_mistakes =  0.27274935876
# , right_weighted_mistakes =  0.224078264206 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.1 year
# inside best_feature_split(): left_weighted_mistakes =  0.461796079208
# , right_weighted_mistakes =  0.0350315437579 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.10+ years
# inside best_feature_split(): left_weighted_mistakes =  0.357878397592
# , right_weighted_mistakes =  0.138346522582 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.2 years
# inside best_feature_split(): left_weighted_mistakes =  0.448221879886
# , right_weighted_mistakes =  0.0478334562598 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.3 years
# inside best_feature_split(): left_weighted_mistakes =  0.453973333565
# , right_weighted_mistakes =  0.0410959279618 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.4 years
# inside best_feature_split(): left_weighted_mistakes =  0.461481087168
# , right_weighted_mistakes =  0.0346428806237 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.5 years
# inside best_feature_split(): left_weighted_mistakes =  0.458507960434
# , right_weighted_mistakes =  0.0383196625318 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.6 years
# inside best_feature_split(): left_weighted_mistakes =  0.467248386539
# , right_weighted_mistakes =  0.0295792364273 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.7 years
# inside best_feature_split(): left_weighted_mistakes =  0.470299808943
# , right_weighted_mistakes =  0.0265278140227 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.8 years
# inside best_feature_split(): left_weighted_mistakes =  0.475516980113
# , right_weighted_mistakes =  0.021310642853 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.9 years
# inside best_feature_split(): left_weighted_mistakes =  0.479253022779
# , right_weighted_mistakes =  0.0175746001875 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.< 1 year
# inside best_feature_split(): left_weighted_mistakes =  0.451683547165
# , right_weighted_mistakes =  0.0451440758009 , sum of data_weights =  1.0
# inside best_splitting_feature():, the current feature is:  emp_length.n/a
# inside best_feature_split(): left_weighted_mistakes =  0.479243369235
# , right_weighted_mistakes =  0.0175842537314 , sum of data_weights =  1.0
# Split on feature grade.C. (27812, 9412)
# --------------------------------------------------------------------
# Subtree, depth = 2 (27812 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (9412 data points).
# Reached maximum depth. Stopping for now.
# weight_error =  0.494348454041
# weights =  0.011303573315
# total_alpha =  0.999936118016
# after adjusting, the correct data weights =  [1.7370320693395374e-05, 2.3742747820872908e-05, 3.1234627677383965e-05, 3.1234627677383965e-05, 3.1234627677383965e-05]
# after adjusting, the wrong data weights =  [2.0425492941253976e-05, 2.687063317019415e-05, 2.687063317019415e-05, 2.808916812797133e-05, 3.10876830419923e-05]

# %% [markdown]
# ### Computing training error at the end of each iteration
#
# Now, we will compute the classification error on the **train_data** and see how it is reduced as trees are added.

# %%
error_all = []
for n in xrange(1, 31):
    predictions = predict_adaboost(stump_weights[:n], tree_stumps[:n], train_data)
    error = 1.0 - graphlab.evaluation.accuracy(train_data[target], predictions)
    error_all.append(error)
    print "Iteration %s, training error = %s" % (n, error_all[n-1])
# Out:
# Iteration 1, training error = 0.421636578551
# Iteration 2, training error = 0.433430045132
# Iteration 3, training error = 0.400037610144
# Iteration 4, training error = 0.400037610144
# Iteration 5, training error = 0.384724908661
# Iteration 6, training error = 0.384617451107
# Iteration 7, training error = 0.382763808296
# Iteration 8, training error = 0.384617451107
# Iteration 9, training error = 0.382763808296
# Iteration 10, training error = 0.384483129164
# Iteration 11, training error = 0.382736943907
# Iteration 12, training error = 0.381447453256
# Iteration 13, training error = 0.381528046422
# Iteration 14, training error = 0.380560928433
# Iteration 15, training error = 0.380507199656
# Iteration 16, training error = 0.378223726628
# Iteration 17, training error = 0.378277455405
# Iteration 18, training error = 0.378411777348
# Iteration 19, training error = 0.378062540297
# Iteration 20, training error = 0.378761014399
# Iteration 21, training error = 0.379566946056
# Iteration 22, training error = 0.378895336342
# Iteration 23, training error = 0.378895336342
# Iteration 24, training error = 0.378761014399
# Iteration 25, training error = 0.378895336342
# Iteration 26, training error = 0.378975929508
# Iteration 27, training error = 0.379110251451
# Iteration 28, training error = 0.378922200731
# Iteration 29, training error = 0.379029658285
# Iteration 30, training error = 0.378734150011

# %% [markdown]
# ### Visualizing training error vs number of iterations
#
# We have provided you with a simple code snippet that plots classification error with the number of iterations.

# %%
plt.rcParams['figure.figsize'] = 7, 5
plt.plot(range(1,31), error_all, '-', linewidth=4.0, label='Training error')
plt.title('Performance of Adaboost ensemble')
plt.xlabel('# of iterations')
plt.ylabel('Classification error')
plt.legend(loc='best', prop={'size':15})

plt.rcParams.update({'font.size': 16})

# %% [markdown]
# **Quiz Question**: Which of the following best describes a **general trend in accuracy** as we add more and more components? Answer based on the 30 components learned so far.
#
# 1. Training error goes down monotonically, i.e. the training error reduces with each iteration but never increases.
# 2. Training error goes down in general, with some ups and downs in the middle.
# 3. Training error goes up in general, with some ups and downs in the middle.
# 4. Training error goes down in the beginning, achieves the best error, and then goes up sharply.
# 5. None of the above
#
#
# ### Evaluation on the test data
#
# Performing well on the training data is cheating, so lets make sure it works on the `test_data` as well. Here, we will compute the classification error on the `test_data` at the end of each iteration.

# %%
test_error_all = []
for n in xrange(1, 31):
    predictions = predict_adaboost(stump_weights[:n], tree_stumps[:n], test_data)
    error = 1.0 - graphlab.evaluation.accuracy(test_data[target], predictions)
    test_error_all.append(error)
    print "Iteration %s, test error = %s" % (n, test_error_all[n-1])
# Out:
# Iteration 1, test error = 0.42330891857
# Iteration 2, test error = 0.428479103835
# Iteration 3, test error = 0.398104265403
# Iteration 4, test error = 0.398104265403
# Iteration 5, test error = 0.379900904782
# Iteration 6, test error = 0.380008616975
# Iteration 7, test error = 0.379254631624
# Iteration 8, test error = 0.380008616975
# Iteration 9, test error = 0.379254631624
# Iteration 10, test error = 0.379685480396
# Iteration 11, test error = 0.379254631624
# Iteration 12, test error = 0.377962085308
# Iteration 13, test error = 0.379254631624
# Iteration 14, test error = 0.377854373115
# Iteration 15, test error = 0.378500646273
# Iteration 16, test error = 0.377854373115
# Iteration 17, test error = 0.377962085308
# Iteration 18, test error = 0.377854373115
# Iteration 19, test error = 0.378177509694
# Iteration 20, test error = 0.376884963378
# Iteration 21, test error = 0.377531236536
# Iteration 22, test error = 0.376777251185
# Iteration 23, test error = 0.376777251185
# Iteration 24, test error = 0.376884963378
# Iteration 25, test error = 0.376777251185
# Iteration 26, test error = 0.376561826799
# Iteration 27, test error = 0.376454114606
# Iteration 28, test error = 0.376992675571
# Iteration 29, test error = 0.376777251185
# Iteration 30, test error = 0.376777251185

# %% [markdown]
# ### Visualize both the training and test errors
#
# Now, let us plot the training & test error with the number of iterations.

# %%
plt.rcParams['figure.figsize'] = 7, 5
plt.plot(range(1,31), error_all, '-', linewidth=4.0, label='Training error')
plt.plot(range(1,31), test_error_all, '-', linewidth=4.0, label='Test error')

plt.title('Performance of Adaboost ensemble')
plt.xlabel('# of iterations')
plt.ylabel('Classification error')
plt.rcParams.update({'font.size': 16})
plt.legend(loc='best', prop={'size':15})
plt.tight_layout()

# %% [markdown]
# ** Quiz Question:** From this plot (with 30 trees), is there massive overfitting as the # of iterations increases?
